# %%
import pyodbc
from collections import defaultdict, deque
import heapq
import pandas as pd
import time



class Program:
    def __init__(self, inst_code, brcode, capacity):
        self.inst_code = inst_code
        self.brcode = brcode
        self.capacity = capacity
        self.waitlist = []  # Will store tuples (roll_no, rank)
        
    def add_candidate(self, candidate):
        # Insert candidate into the heap as a tuple of (-rank, roll_no)
        heapq.heappush(self.waitlist, (-candidates[candidate].adv, candidate))

    def remove_least_preferred(self):
        # Remove the candidate with the highest positive rank (least preferred)
        return heapq.heappop(self.waitlist.candidate)

# Example dictionaries for demonstration
class Candidate:
    def __init__(self, roll_no, adv, mains):
        self.roll_no = roll_no
        self.adv = adv
        self.mains = mains
        self.current_index = 1
        
# Load data from CSV files
def load_candidates(filename):
    df = pd.read_csv(filename)
    return {row['RollNo']: Candidate(row['RollNo'], row['Adv_CRL_Rank'],row['AI_Eng_CRL_Rank']) for index, row in df.iterrows()}

def load_programs(filename):
    df = pd.read_csv(filename)
    return {(row['InstCode'], row['Brcode']): Program(row['InstCode'], row['Brcode'], row['TotalSeat']) for index, row in df.iterrows()}

def load_choices(filename):
    df = pd.read_csv(filename)
    return df

# Example file paths
candidates = load_candidates(r'C:\Users\student\Desktop\JOSAA\data\Round1-20240508T102918Z-001\Round1\Candidate.csv')
programs = load_programs(r'C:\Users\student\Desktop\JOSAA\data\Round1-20240508T102918Z-001\Round1\Seats.csv')
choices = load_choices(r'C:\Users\student\Desktop\JOSAA\data\Round1-20240508T102918Z-001\Round1\Choice.csv')

# Function to get preferences based on Choices DataFrame
def get_preference(roll_no, choice_no, choices_df):
    row = choices_df[(choices_df['RollNo'] == roll_no) & (choices_df['ChoiceNo'] == choice_no)]
    if not row.empty:
        inst_code, br_code = row.iloc[0]['InstCode'], row.iloc[0]['Brcode']
        return programs.get((inst_code, br_code))
    return None

# %%
# # Example usage
# prgm = getPreference(230310481885, 1)
# if prgm:
#     print(f'{prgm.capacity}')
# else:
#     print("No Program")


# for roll_no in candidates:
#     print(f"Roll Number: {roll_no}, Adv Rank: {candidates[roll_no].adv}, AI Rank: {candidates[roll_no].mains}")
# Out:
# 59

# %%
queue = deque([candidates[roll_no] for roll_no in candidates])
    
    
def process_candidates(programs, candidates, queue):

    # Allocation dictionary to track which program each candidate ends up with
    allocations = {}
    start_time = time.time()  # Start timing
    

    while queue:
        candidate = queue.popleft()
        program = get_preference(candidate.roll_no, candidates[candidate.roll_no].current_index)

        # Ensure program exists and candidate is eligible (capacity check here for simplicity)
        if program and program.capacity > 0:
            # Simulate allocation
            program.waitlist.append(candidate.roll_no)
            allocations[candidate.roll_no] = program
            # program.capacity -= 1  # Decrement the available seats
            
            # Handle over-capacity by removing the last candidate (simplest method for demonstration)
            if len(program.waitlist) > program.capacity:
                removed_roll_no = program.waitlist.pop(0)  # Remove the first candidate to simulate FIFO
                allocations.pop(removed_roll_no, None)  # Remove from allocations
                candidates[removed_roll_no].current_index += 1  # Move to next preference
                queue.append(candidates[removed_roll_no])  # Re-enqueue the candidate
    end_time = time.time()  # End timing
    print(f"Time taken: {end_time - start_time:.2f} seconds")
    return allocations, programs


allocations, final_programs = process_candidates(programs, candidates, queue)

# Printing the results
print("Final Allocations:")
for roll_no, program_key in allocations.items():
    print(f"Candidate {roll_no} is allocated to program {program_key.inst_code}\'s  {program_key.brcode}")

print("\nFinal Waitlists:")
for program_key, program in final_programs.items():
    print(f"Program {program_key} waitlist: {program.waitlist} with {program.capacity - len(program.waitlist)} remaining seats")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 56
#      30     return allocations, programs
#      34 # def process_candidates(programs, candidates, queue):
#      35 #     allocations = {}
#      36 #     start_time = time.time()  # Start timing
#    (...)
#      50
#      51 # # Assuming `programs` and `candidates` are already initialized and `queue` is set up:
# ---> 56 allocations, final_programs = process_candidates(programs, candidates, queue)
#      58 # Printing the results
#      59 print("Final Allocations:")
#
# Cell In[63], line 13, in process_candidates(programs, candidates, queue)
#      11 while queue:
#      12     candidate = queue.popleft()
# ---> 13     program = get_preference(candidate.roll_no, candidates[candidate.roll_no].current_index)
#      15     # Ensure program exists and candidate is eligible (capacity check here for simplicity)
#      16     if program and program.capacity > 0:
#      17         # Simulate allocation
#
# TypeError: get_preference() missing 1 required positional argument: 'choices_df'

# %%
# Out:
# Requirement already satisfied: tqdm in c:\users\student\appdata\local\programs\python\python312\lib\site-packages (4.66.4)
# Requirement already satisfied: colorama in c:\users\student\appdata\roaming\python\python312\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from collections import deque
import heapq
import time

class Program:
    def __init__(self, inst_code, brcode, capacity):
        self.inst_code = inst_code
        self.brcode = brcode
        self.capacity = capacity
        self.waitlist = []  # Will store tuples (negative rank, roll_no)

    def add_candidate(self, candidate):
        # Insert candidate into the heap as a tuple of (-rank, roll_no)
        heapq.heappush(self.waitlist, (-candidate.adv, candidate.roll_no))

    def remove_least_preferred(self):
        # Remove the candidate with the highest positive rank (least preferred)
        return heapq.heappop(self.waitlist)

class Candidate:
    def __init__(self, roll_no, adv_rank, mains_rank):
        self.roll_no = roll_no
        self.adv = adv_rank
        self.mains = mains_rank
        self.current_index = 1  # Initialize to 1 assuming choice numbers start from 1

# Load data from CSV files
def load_candidates(filename):
    df = pd.read_csv(filename)
    filtered_df = df[(df['Adv_CRL_Rank'] > 0) & 
                     (df['Gender'] == 'B') & 
                     (df['Cat'] == 'OP') & 
                     (df['SubCat'] == 'NO')].sort_values('Adv_CRL_Rank').head(100)
    return {row['RollNo']: Candidate(row['RollNo'], row['Adv_CRL_Rank'], row['AI_Eng_CRL_Rank']) for index, row in filtered_df.iterrows()}


def load_programs(filename):
    df = pd.read_csv(filename)
    return {(row['InstCode'], row['Brcode']): Program(row['InstCode'], row['Brcode'], row['TotalSeat']) for index, row in df.iterrows()}

def load_choices(filename):
    df = pd.read_csv(filename)
    return df

# Example file paths
candidates = load_candidates(r'C:\Users\student\Desktop\JOSAA\data\Round1-20240508T102918Z-001\Round1\Candidate.csv')
programs = load_programs(r'C:\Users\student\Desktop\JOSAA\data\Round1-20240508T102918Z-001\Round1\Seats.csv')
choices = load_choices(r'C:\Users\student\Desktop\JOSAA\data\Round1-20240508T102918Z-001\Round1\Choice.csv')

# Function to get preferences based on Choices DataFrame
def get_preference(roll_no, choice_no, choices_df):
    row = choices_df[(choices_df['RollNo'] == roll_no) & (choices_df['ChoiceNo'] == choice_no)]
    if not row.empty:
        inst_code, br_code = row.iloc[0]['InstCode'], row.iloc[0]['Brcode']
        return programs.get((inst_code, br_code))
    return None

# Processing candidates
queue = deque(sorted(candidates.values(), key=lambda c: c.adv))  # Sort by advanced rank for processing
# queue = deque([candidates[roll_no] for roll_no in candidates])

def process_candidates():
    start_time = time.time()
    allocations = {}
    while queue:
        candidate = queue.popleft()
        preference = get_preference(candidate.roll_no, candidate.current_index, choices)
        if preference and preference.capacity > 0:
            preference.add_candidate(candidate)
            allocations[candidate.roll_no] = (preference.inst_code, preference.brcode)
            if len(preference.waitlist) > preference.capacity:
                _, removed_roll_no = preference.remove_least_preferred()
                allocations.pop(removed_roll_no)
                candidate.current_index += 1
                queue.append(candidates[removed_roll_no])  # Add back to the queue if not placed
    print(f"Time taken: {time.time() - start_time:.2f} seconds")
    return allocations, programs

allocations , final_programs = process_candidates()

# Printing the results
print("Final Allocations:")
for roll_no, program_key in allocations.items():
    print(f"Candidate {roll_no} is allocated to program {program_key.inst_code}\'s  {program_key.brcode}")

print("\nFinal Waitlists:")
for program_key, program in final_programs.items():
    print(f"Program {program_key} waitlist: {program.waitlist} with {program.capacity - len(program.waitlist)} remaining seats")
# Out:
# Time taken: 6.45 seconds
# Final Allocations:
#
# Final Waitlists:
# Program (101, '4109') waitlist: [] with 0 remaining seats
# Program (101, '4110') waitlist: [] with 0 remaining seats
# Program (101, '4111') waitlist: [] with 0 remaining seats
# Program (101, '4114') waitlist: [] with 0 remaining seats
# Program (101, '4125') waitlist: [] with 0 remaining seats
# Program (101, '4127') waitlist: [] with 0 remaining seats
# Program (101, '5216') waitlist: [] with 0 remaining seats
# Program (101, '5243') waitlist: [] with 0 remaining seats
# Program (101, '5255') waitlist: [] with 0 remaining seats
# Program (101, '5260') waitlist: [] with 0 remaining seats
# Program (101, '5284') waitlist: [] with 0 remaining seats
# Program (101, '5285') waitlist: [] with 0 remaining seats
# Program (101, '5286') waitlist: [] with 0 remaining seats
# Program (101, '5287') waitlist: [] with 0 remaining seats
# Program (101, '5288') waitlist: [] with 0 remaining seats
# Program (102, '4101') waitlist: [] with 0 remaining seats
# Program (102, '4107') waitlist: [] with 0 remaining seats
# Program (102, '4109') waitlist: [] with 0 remaining seats
# Program (102, '410U') waitlist: [] with 0 remaining seats
# Program (102, '4110') waitlist: [] with 0 remaining seats
# Program (102, '4111') waitlist: [] with 0 remaining seats
# Program (102, '4117') waitlist: [] with 0 remaining seats
# Program (102, '4125') waitlist: [] with 0 remaining seats
# Program (102, '4128') waitlist: [] with 1 remaining seats
# Program (102, '4198') waitlist: [] with 0 remaining seats
# Program (102, '4201') waitlist: [] with 0 remaining seats
# Program (102, '4202') waitlist: [] with 0 remaining seats
# Program (102, '4206') waitlist: [] with 0 remaining seats
# Program (102, '5217') waitlist: [] with 0 remaining seats
# Program (103, '4109') waitlist: [] with 0 remaining seats
# Program (103, '410Y') waitlist: [] with 0 remaining seats
# Program (103, '4110') waitlist: [] with 0 remaining seats
# Program (103, '4111') waitlist: [] with 0 remaining seats
# Program (103, '4117') waitlist: [] with 0 remaining seats
# Program (103, '411D') waitlist: [] with 0 remaining seats
# Program (103, '411E') waitlist: [] with 0 remaining seats
# Program (103, '411F') waitlist: [] with 0 remaining seats
# Program (103, '4125') waitlist: [] with 0 remaining seats
# Program (103, '4143') waitlist: [] with 0 remaining seats
# Program (103, '4187') waitlist: [] with 0 remaining seats
# Program (103, '4213') waitlist: [] with 0 remaining seats
# Program (104, '4105') waitlist: [] with 0 remaining seats
# Program (104, '4107') waitlist: [] with 0 remaining seats
# Program (104, '4109') waitlist: [] with 0 remaining seats
# Program (104, '4110') waitlist: [] with 0 remaining seats
# Program (104, '4111') waitlist: [] with 0 remaining seats
# Program (104, '4112') waitlist: [] with 0 remaining seats
# Program (104, '4117') waitlist: [] with 0 remaining seats
# Program (104, '4124') waitlist: [] with 0 remaining seats
# Program (104, '4125') waitlist: [] with 0 remaining seats
# Program (104, '4136') waitlist: [] with 0 remaining seats
# Program (104, '4139') waitlist: [] with 0 remaining seats
# Program (104, '4192') waitlist: [] with 0 remaining seats
# Program (104, '4193') waitlist: [] with 0 remaining seats
# Program (104, '4198') waitlist: [] with 0 remaining seats
# Program (104, '5210') waitlist: [] with 0 remaining seats
# Program (104, '5216') waitlist: [] with 0 remaining seats
# Program (104, '5254') waitlist: [] with 0 remaining seats
# Program (105, '4107') waitlist: [] with 0 remaining seats
# Program (105, '4109') waitlist: [] with 0 remaining seats
# Program (105, '4110') waitlist: [] with 0 remaining seats
# Program (105, '4111') waitlist: [] with 0 remaining seats
# Program (105, '4117') waitlist: [] with 0 remaining seats
# Program (105, '411L') waitlist: [] with 0 remaining seats
# Program (105, '4124') waitlist: [] with 0 remaining seats
# Program (105, '4125') waitlist: [] with 0 remaining seats
# Program (105, '4128') waitlist: [] with 0 remaining seats
# Program (106, '4101') waitlist: [] with 0 remaining seats
# Program (106, '4102') waitlist: [] with 0 remaining seats
# Program (106, '4105') waitlist: [] with 0 remaining seats
# Program (106, '4107') waitlist: [] with 0 remaining seats
# Program (106, '4109') waitlist: [] with 0 remaining seats
# Program (106, '4110') waitlist: [] with 0 remaining seats
# Program (106, '4111') waitlist: [] with 0 remaining seats
# Program (106, '4115') waitlist: [] with 1 remaining seats
# Program (106, '4121') waitlist: [] with 0 remaining seats
# Program (106, '4122') waitlist: [] with 0 remaining seats
# Program (106, '4125') waitlist: [] with 0 remaining seats
# Program (106, '4127') waitlist: [] with 0 remaining seats
# Program (106, '4130') waitlist: [] with 0 remaining seats
# Program (106, '4133') waitlist: [] with 0 remaining seats
# Program (106, '4170') waitlist: [] with 0 remaining seats
# Program (106, '4201') waitlist: [] with 0 remaining seats
# Program (106, '4202') waitlist: [] with 0 remaining seats
# Program (106, '4204') waitlist: [] with 0 remaining seats
# Program (106, '4208') waitlist: [] with 0 remaining seats
# Program (106, '4209') waitlist: [] with 0 remaining seats
# Program (106, '4210') waitlist: [] with 0 remaining seats
# Program (106, '5101') waitlist: [] with 0 remaining seats
# Program (106, '5201') waitlist: [] with 0 remaining seats
# Program (106, '5203') waitlist: [] with 0 remaining seats
# Program (106, '5208') waitlist: [] with 0 remaining seats
# Program (106, '5210') waitlist: [] with 0 remaining seats
# Program (106, '5215') waitlist: [] with 0 remaining seats
# Program (106, '5216') waitlist: [] with 0 remaining seats
# Program (106, '5222') waitlist: [] with 0 remaining seats
# Program (106, '5225') waitlist: [] with 0 remaining seats
# Program (106, '5239') waitlist: [] with 0 remaining seats
# Program (106, '5241') waitlist: [] with 0 remaining seats
# Program (106, '5243') waitlist: [] with 0 remaining seats
# Program (106, '5247') waitlist: [] with 0 remaining seats
# Program (106, '5248') waitlist: [] with 0 remaining seats
# Program (106, '5251') waitlist: [] with 0 remaining seats
# Program (106, '5281') waitlist: [] with 0 remaining seats
# Program (107, '4107') waitlist: [] with 0 remaining seats
# Program (107, '4109') waitlist: [] with 0 remaining seats
# Program (107, '410A') waitlist: [] with 0 remaining seats
# Program (107, '410B') waitlist: [] with 0 remaining seats
# Program (107, '410T') waitlist: [] with 0 remaining seats
# Program (107, '4110') waitlist: [] with 0 remaining seats
# Program (107, '4111') waitlist: [] with 0 remaining seats
# Program (107, '4117') waitlist: [] with 0 remaining seats
# Program (107, '4118') waitlist: [] with 0 remaining seats
# Program (107, '4124') waitlist: [] with 0 remaining seats
# Program (107, '4125') waitlist: [] with 0 remaining seats
# Program (107, '4161') waitlist: [] with 0 remaining seats
# Program (107, '4185') waitlist: [] with 0 remaining seats
# Program (107, '4191') waitlist: [] with 0 remaining seats
# Program (107, '4199') waitlist: [] with 0 remaining seats
# Program (108, '4107') waitlist: [] with 0 remaining seats
# Program (108, '4110') waitlist: [] with 0 remaining seats
# Program (108, '4111') waitlist: [] with 0 remaining seats
# Program (108, '4125') waitlist: [] with 0 remaining seats
# Program (108, '4141') waitlist: [] with 0 remaining seats
# Program (108, '4143') waitlist: [] with 0 remaining seats
# Program (108, '4188') waitlist: [] with 0 remaining seats
# Program (108, '4193') waitlist: [] with 0 remaining seats
# Program (108, '4211') waitlist: [] with 0 remaining seats
# Program (108, '4212') waitlist: [] with 0 remaining seats
# Program (109, '4101') waitlist: [] with 0 remaining seats
# Program (109, '4103') waitlist: [] with 0 remaining seats
# Program (109, '4107') waitlist: [] with 0 remaining seats
# Program (109, '4109') waitlist: [] with 0 remaining seats
# Program (109, '4110') waitlist: [] with 0 remaining seats
# Program (109, '4111') waitlist: [] with 0 remaining seats
# Program (109, '4123') waitlist: [] with 0 remaining seats
# Program (109, '4125') waitlist: [] with 0 remaining seats
# Program (109, '4201') waitlist: [] with 0 remaining seats
# Program (109, '4202') waitlist: [] with 0 remaining seats
# Program (109, '4203') waitlist: [] with 0 remaining seats
# Program (109, '4204') waitlist: [] with 0 remaining seats
# Program (109, '4205') waitlist: [] with 0 remaining seats
# Program (109, '4207') waitlist: [] with 0 remaining seats
# Program (110, '4101') waitlist: [] with 0 remaining seats
# Program (110, '4107') waitlist: [] with 0 remaining seats
# Program (110, '4109') waitlist: [] with 0 remaining seats
# Program (110, '4110') waitlist: [] with 0 remaining seats
# Program (110, '4111') waitlist: [] with 0 remaining seats
# Program (110, '4117') waitlist: [] with 0 remaining seats
# Program (110, '411N') waitlist: [] with 0 remaining seats
# Program (110, '4125') waitlist: [] with 0 remaining seats
# Program (110, '4127') waitlist: [] with 0 remaining seats
# Program (110, '4132') waitlist: [] with 0 remaining seats
# Program (110, '4214') waitlist: [] with 0 remaining seats
# Program (110, '5201') waitlist: [] with 0 remaining seats
# Program (110, '5227') waitlist: [] with 0 remaining seats
# Program (110, '5602') waitlist: [] with 0 remaining seats
# Program (111, '4107') waitlist: [] with 0 remaining seats
# Program (111, '4109') waitlist: [] with 0 remaining seats
# Program (111, '4110') waitlist: [] with 0 remaining seats
# Program (111, '4111') waitlist: [] with 0 remaining seats
# Program (111, '4125') waitlist: [] with 0 remaining seats
# Program (111, '4185') waitlist: [] with 0 remaining seats
# Program (111, '4193') waitlist: [] with 0 remaining seats
# Program (111, '5216') waitlist: [] with 0 remaining seats
# Program (111, '5217') waitlist: [] with 0 remaining seats
# Program (111, '5233') waitlist: [] with 0 remaining seats
# Program (112, '4107') waitlist: [] with 0 remaining seats
# Program (112, '4108') waitlist: [] with 0 remaining seats
# Program (112, '4109') waitlist: [] with 0 remaining seats
# Program (112, '4110') waitlist: [] with 0 remaining seats
# Program (112, '4114') waitlist: [] with 0 remaining seats
# Program (112, '4117') waitlist: [] with 0 remaining seats
# Program (112, '4124') waitlist: [] with 0 remaining seats
# Program (112, '4125') waitlist: [] with 0 remaining seats
# Program (112, '4127') waitlist: [] with 0 remaining seats
# Program (112, '4144') waitlist: [] with 0 remaining seats
# Program (112, '4188') waitlist: [] with 0 remaining seats
# Program (112, '521Q') waitlist: [] with 0 remaining seats
# Program (112, '5404') waitlist: [] with 0 remaining seats
# Program (112, '5A03') waitlist: [] with 0 remaining seats
# Program (112, '5A04') waitlist: [] with 0 remaining seats
# Program (112, '5A05') waitlist: [] with 0 remaining seats
# Program (112, '5A06') waitlist: [] with 0 remaining seats
# Program (112, '5A07') waitlist: [] with 0 remaining seats
# Program (112, '5A09') waitlist: [] with 0 remaining seats
# Program (112, '5A10') waitlist: [] with 0 remaining seats
# Program (113, '4107') waitlist: [] with 0 remaining seats
# Program (113, '4109') waitlist: [] with 0 remaining seats
# Program (113, '4110') waitlist: [] with 0 remaining seats
# Program (113, '4111') waitlist: [] with 0 remaining seats
# Program (113, '4114') waitlist: [] with 0 remaining seats
# Program (113, '4117') waitlist: [] with 0 remaining seats
# Program (113, '4125') waitlist: [] with 0 remaining seats
# Program (113, '4127') waitlist: [] with 1 remaining seats
# Program (113, '4136') waitlist: [] with 0 remaining seats
# Program (113, '4181') waitlist: [] with 0 remaining seats
# Program (113, '4194') waitlist: [] with 0 remaining seats
# Program (113, '5101') waitlist: [] with 0 remaining seats
# Program (113, '5302') waitlist: [] with 0 remaining seats
# Program (113, '5303') waitlist: [] with 0 remaining seats
# Program (113, '5602') waitlist: [] with 0 remaining seats
# Program (113, '5606') waitlist: [] with 0 remaining seats
# Program (113, '5607') waitlist: [] with 0 remaining seats
# Program (113, '5608') waitlist: [] with 0 remaining seats
# Program (114, '4107') waitlist: [] with 0 remaining seats
# Program (114, '4109') waitlist: [] with 0 remaining seats
# Program (114, '4110') waitlist: [] with 0 remaining seats
# Program (114, '4111') waitlist: [] with 0 remaining seats
# Program (114, '4114') waitlist: [] with 0 remaining seats
# Program (114, '4117') waitlist: [] with 0 remaining seats
# Program (114, '4119') waitlist: [] with 0 remaining seats
# Program (114, '4125') waitlist: [] with 0 remaining seats
# Program (114, '4130') waitlist: [] with 0 remaining seats
# Program (114, '4131') waitlist: [] with 0 remaining seats
# Program (114, '4134') waitlist: [] with 0 remaining seats
# Program (114, '4189') waitlist: [] with 0 remaining seats
# Program (114, '5305') waitlist: [] with 0 remaining seats
# Program (114, '5306') waitlist: [] with 0 remaining seats
# Program (114, '5307') waitlist: [] with 0 remaining seats
# Program (115, '4107') waitlist: [] with 0 remaining seats
# Program (115, '4109') waitlist: [] with 0 remaining seats
# Program (115, '4110') waitlist: [] with 0 remaining seats
# Program (115, '4111') waitlist: [] with 0 remaining seats
# Program (115, '4117') waitlist: [] with 0 remaining seats
# Program (115, '411G') waitlist: [] with 0 remaining seats
# Program (115, '4124') waitlist: [] with 0 remaining seats
# Program (115, '4125') waitlist: [] with 0 remaining seats
# Program (115, '4127') waitlist: [] with 0 remaining seats
# Program (116, '4106') waitlist: [] with 0 remaining seats
# Program (116, '4107') waitlist: [] with 0 remaining seats
# Program (116, '4109') waitlist: [] with 0 remaining seats
# Program (116, '4110') waitlist: [] with 0 remaining seats
# Program (116, '4111') waitlist: [] with 1 remaining seats
# Program (116, '4113') waitlist: [] with 0 remaining seats
# Program (116, '4125') waitlist: [] with 0 remaining seats
# Program (116, '4126') waitlist: [] with 0 remaining seats
# Program (116, '4130') waitlist: [] with 0 remaining seats
# Program (116, '4173') waitlist: [] with 0 remaining seats
# Program (116, '5101') waitlist: [] with 0 remaining seats
# Program (116, '5204') waitlist: [] with 0 remaining seats
# Program (116, '5206') waitlist: [] with 0 remaining seats
# Program (116, '5209') waitlist: [] with 0 remaining seats
# Program (116, '5213') waitlist: [] with 0 remaining seats
# Program (116, '5216') waitlist: [] with 0 remaining seats
# Program (116, '5223') waitlist: [] with 0 remaining seats
# Program (116, '5232') waitlist: [] with 0 remaining seats
# Program (116, '5233') waitlist: [] with 0 remaining seats
# Program (116, '5240') waitlist: [] with 0 remaining seats
# Program (116, '5247') waitlist: [] with 0 remaining seats
# Program (116, '5254') waitlist: [] with 0 remaining seats
# Program (116, '5267') waitlist: [] with 0 remaining seats
# Program (116, '5290') waitlist: [] with 0 remaining seats
# Program (116, '5291') waitlist: [] with 0 remaining seats
# Program (117, '4107') waitlist: [] with 0 remaining seats
# Program (117, '4108') waitlist: [] with 0 remaining seats
# Program (117, '4109') waitlist: [] with 0 remaining seats
# Program (117, '4110') waitlist: [] with 0 remaining seats
# Program (117, '4114') waitlist: [] with 0 remaining seats
# Program (117, '4116') waitlist: [] with 0 remaining seats
# Program (117, '4117') waitlist: [] with 0 remaining seats
# Program (117, '4124') waitlist: [] with 0 remaining seats
# Program (117, '4125') waitlist: [] with 0 remaining seats
# Program (117, '4181') waitlist: [] with 0 remaining seats
# Program (117, '4194') waitlist: [] with 0 remaining seats
# Program (117, '4198') waitlist: [] with 0 remaining seats
# Program (118, '4110') waitlist: [] with 0 remaining seats
# Program (118, '4111') waitlist: [] with 0 remaining seats
# Program (118, '4125') waitlist: [] with 0 remaining seats
# Program (118, '4161') waitlist: [] with 0 remaining seats
# Program (118, '4178') waitlist: [] with 0 remaining seats
# Program (118, '4181') waitlist: [] with 0 remaining seats
# Program (119, '4110') waitlist: [] with 0 remaining seats
# Program (119, '4111') waitlist: [] with 1 remaining seats
# Program (119, '4124') waitlist: [] with 0 remaining seats
# Program (119, '4125') waitlist: [] with 0 remaining seats
# Program (120, '4109') waitlist: [] with 0 remaining seats
# Program (120, '4110') waitlist: [] with 0 remaining seats
# Program (120, '4111') waitlist: [] with 0 remaining seats
# Program (120, '4125') waitlist: [] with 0 remaining seats
# Program (120, '4187') waitlist: [] with 0 remaining seats
# Program (121, '4107') waitlist: [] with 0 remaining seats
# Program (121, '4109') waitlist: [] with 0 remaining seats
# Program (121, '4110') waitlist: [] with 0 remaining seats
# Program (121, '4111') waitlist: [] with 0 remaining seats
# Program (121, '4125') waitlist: [] with 0 remaining seats
# Program (122, '4107') waitlist: [] with 0 remaining seats
# Program (122, '4109') waitlist: [] with 0 remaining seats
# Program (122, '4110') waitlist: [] with 0 remaining seats
# Program (122, '4111') waitlist: [] with 0 remaining seats
# Program (122, '4124') waitlist: [] with 0 remaining seats
# Program (122, '4125') waitlist: [] with 1 remaining seats
# Program (122, '4193') waitlist: [] with 0 remaining seats
# Program (123, '410D') waitlist: [] with 0 remaining seats
# Program (123, '4110') waitlist: [] with 0 remaining seats
# Program (123, '4111') waitlist: [] with 0 remaining seats
# Program (123, '4117') waitlist: [] with 0 remaining seats
# Program (123, '4124') waitlist: [] with 0 remaining seats
# Program (123, '4125') waitlist: [] with 0 remaining seats
# Program (123, '4141') waitlist: [] with 0 remaining seats
# Program (123, '5609') waitlist: [] with 0 remaining seats
# Program (301, '4110') waitlist: [] with 0 remaining seats
# Program (301, '411M') waitlist: [] with 0 remaining seats
# Program (301, '4144') waitlist: [] with 0 remaining seats
# Program (301, '5B01') waitlist: [] with 0 remaining seats
# Program (301, '5C01') waitlist: [] with 0 remaining seats
# Program (302, '4110') waitlist: [] with 0 remaining seats
# Program (302, '4114') waitlist: [] with 0 remaining seats
# Program (303, '4110') waitlist: [] with 0 remaining seats
# Program (303, '4114') waitlist: [] with 0 remaining seats
# Program (304, '4110') waitlist: [] with 0 remaining seats
# Program (304, '4114') waitlist: [] with 0 remaining seats
# Program (305, '4110') waitlist: [] with 0 remaining seats
# Program (305, '4146') waitlist: [] with 0 remaining seats
# Program (306, '4110') waitlist: [] with 0 remaining seats
# Program (306, '4114') waitlist: [] with 0 remaining seats
# Program (306, '4146') waitlist: [] with 0 remaining seats
# Program (307, '4110') waitlist: [] with 0 remaining seats
# Program (307, '4114') waitlist: [] with 0 remaining seats
# Program (307, '4188') waitlist: [] with 0 remaining seats
# Program (308, '4110') waitlist: [] with 0 remaining seats
# Program (308, '4146') waitlist: [] with 0 remaining seats
# Program (309, '4114') waitlist: [] with 0 remaining seats
# Program (309, '4146') waitlist: [] with 0 remaining seats
# Program (309, '4186') waitlist: [] with 0 remaining seats
# Program (310, '4110') waitlist: [] with 0 remaining seats
# Program (310, '4114') waitlist: [] with 0 remaining seats
# Program (310, '4125') waitlist: [] with 0 remaining seats
# Program (310, '4176') waitlist: [] with 0 remaining seats
# Program (310, '4196') waitlist: [] with 0 remaining seats
# Program (310, '5216') waitlist: [] with 0 remaining seats
# Program (310, '521P') waitlist: [] with 0 remaining seats
# Program (310, '521Q') waitlist: [] with 0 remaining seats
# Program (311, '4110') waitlist: [] with 1 remaining seats
# Program (311, '4114') waitlist: [] with 0 remaining seats
# Program (311, '4125') waitlist: [] with 0 remaining seats
# Program (311, '4176') waitlist: [] with 0 remaining seats
# Program (313, '410M') waitlist: [] with 0 remaining seats
# Program (313, '410R') waitlist: [] with 0 remaining seats
# Program (313, '4110') waitlist: [] with 0 remaining seats
# Program (313, '4114') waitlist: [] with 0 remaining seats
# Program (314, '4110') waitlist: [] with 0 remaining seats
# Program (314, '4114') waitlist: [] with 0 remaining seats
# Program (315, '410C') waitlist: [] with 0 remaining seats
# Program (315, '4146') waitlist: [] with 0 remaining seats
# Program (315, '4184') waitlist: [] with 0 remaining seats
# Program (315, '4190') waitlist: [] with 0 remaining seats
# Program (316, '4110') waitlist: [] with 0 remaining seats
# Program (316, '4114') waitlist: [] with 0 remaining seats
# Program (316, '4181') waitlist: [] with 0 remaining seats
# Program (317, '4110') waitlist: [] with 0 remaining seats
# Program (317, '4174') waitlist: [] with 0 remaining seats
# Program (317, '4175') waitlist: [] with 0 remaining seats
# Program (317, '4188') waitlist: [] with 0 remaining seats
# Program (317, '5216') waitlist: [] with 0 remaining seats
# Program (317, '5233') waitlist: [] with 0 remaining seats
# Program (317, '5234') waitlist: [] with 0 remaining seats
# Program (318, '410R') waitlist: [] with 0 remaining seats
# Program (318, '4110') waitlist: [] with 0 remaining seats
# Program (318, '4114') waitlist: [] with 0 remaining seats
# Program (318, '4195') waitlist: [] with 0 remaining seats
# Program (319, '4110') waitlist: [] with 0 remaining seats
# Program (319, '4114') waitlist: [] with 0 remaining seats
# Program (319, '4601') waitlist: [] with 0 remaining seats
# Program (319, '4602') waitlist: [] with 0 remaining seats
# Program (320, '410E') waitlist: [] with 0 remaining seats
# Program (320, '410F') waitlist: [] with 0 remaining seats
# Program (320, '410G') waitlist: [] with 0 remaining seats
# Program (320, '410H') waitlist: [] with 0 remaining seats
# Program (320, '4110') waitlist: [] with 0 remaining seats
# Program (320, '4114') waitlist: [] with 0 remaining seats
# Program (321, '4110') waitlist: [] with 0 remaining seats
# Program (321, '4114') waitlist: [] with 0 remaining seats
# Program (322, '4110') waitlist: [] with 0 remaining seats
# Program (322, '4114') waitlist: [] with 0 remaining seats
# Program (322, '411B') waitlist: [] with 0 remaining seats
# Program (322, '4124') waitlist: [] with 0 remaining seats
# Program (323, '4110') waitlist: [] with 0 remaining seats
# Program (323, '4114') waitlist: [] with 0 remaining seats
# Program (323, '4146') waitlist: [] with 0 remaining seats
# Program (324, '4110') waitlist: [] with 0 remaining seats
# Program (324, '4114') waitlist: [] with 0 remaining seats
# Program (325, '4110') waitlist: [] with 0 remaining seats
# Program (326, '4110') waitlist: [] with 0 remaining seats
# Program (326, '4188') waitlist: [] with 0 remaining seats
# Program (327, '4110') waitlist: [] with 0 remaining seats
# Program (401, '4110') waitlist: [] with 0 remaining seats
# Program (401, '4114') waitlist: [] with 0 remaining seats
# Program (401, '4168') waitlist: [] with 0 remaining seats
# Program (402, '4104') waitlist: [] with 0 remaining seats
# Program (402, '4107') waitlist: [] with 0 remaining seats
# Program (402, '4109') waitlist: [] with 0 remaining seats
# Program (402, '410P') waitlist: [] with 0 remaining seats
# Program (402, '4110') waitlist: [] with 0 remaining seats
# Program (402, '4114') waitlist: [] with 0 remaining seats
# Program (402, '4125') waitlist: [] with 0 remaining seats
# Program (402, '4136') waitlist: [] with 0 remaining seats
# Program (402, '4144') waitlist: [] with 0 remaining seats
# Program (402, '4167') waitlist: [] with 0 remaining seats
# Program (402, '5101') waitlist: [] with 0 remaining seats
# Program (402, '5506') waitlist: [] with 0 remaining seats
# Program (402, '5507') waitlist: [] with 0 remaining seats
# Program (402, '5511') waitlist: [] with 0 remaining seats
# Program (403, '4110') waitlist: [] with 0 remaining seats
# Program (403, '4111') waitlist: [] with 0 remaining seats
# Program (403, '4114') waitlist: [] with 0 remaining seats
# Program (403, '4125') waitlist: [] with 0 remaining seats
# Program (404, '4160') waitlist: [] with 0 remaining seats
# Program (405, '4109') waitlist: [] with 0 remaining seats
# Program (405, '4111') waitlist: [] with 0 remaining seats
# Program (405, '4125') waitlist: [] with 0 remaining seats
# Program (405, '4151') waitlist: [] with 0 remaining seats
# Program (406, '4107') waitlist: [] with 0 remaining seats
# Program (406, '4109') waitlist: [] with 0 remaining seats
# Program (406, '4110') waitlist: [] with 0 remaining seats
# Program (406, '4114') waitlist: [] with 0 remaining seats
# Program (406, '4125') waitlist: [] with 0 remaining seats
# Program (406, '4146') waitlist: [] with 0 remaining seats
# Program (406, '4149') waitlist: [] with 0 remaining seats
# Program (407, '4110') waitlist: [] with 0 remaining seats
# Program (407, '4114') waitlist: [] with 0 remaining seats
# Program (408, '4137') waitlist: [] with 0 remaining seats
# Program (409, '4125') waitlist: [] with 0 remaining seats
# Program (409, '4136') waitlist: [] with 0 remaining seats
# Program (409, '4151') waitlist: [] with 0 remaining seats
# Program (409, '4156') waitlist: [] with 0 remaining seats
# Program (410, '4107') waitlist: [] with 0 remaining seats
# Program (410, '4110') waitlist: [] with 0 remaining seats
# Program (410, '4111') waitlist: [] with 0 remaining seats
# Program (410, '4114') waitlist: [] with 0 remaining seats
# Program (410, '4125') waitlist: [] with 0 remaining seats
# Program (410, '4148') waitlist: [] with 0 remaining seats
# Program (410, '4164') waitlist: [] with 0 remaining seats
# Program (411, '4109') waitlist: [] with 0 remaining seats
# Program (411, '4111') waitlist: [] with 0 remaining seats
# Program (411, '4114') waitlist: [] with 0 remaining seats
# Program (411, '4146') waitlist: [] with 0 remaining seats
# Program (411, '4151') waitlist: [] with 0 remaining seats
# Program (411, '5101') waitlist: [] with 0 remaining seats
# Program (412, '4109') waitlist: [] with 0 remaining seats
# Program (412, '4110') waitlist: [] with 0 remaining seats
# Program (412, '4111') waitlist: [] with 0 remaining seats
# Program (412, '4114') waitlist: [] with 0 remaining seats
# Program (412, '4125') waitlist: [] with 0 remaining seats
# Program (412, '4167') waitlist: [] with 0 remaining seats
# Program (413, '4501') waitlist: [] with 0 remaining seats
# Program (413, '5101') waitlist: [] with 0 remaining seats
# Program (414, '4501') waitlist: [] with 0 remaining seats
# Program (414, '5101') waitlist: [] with 0 remaining seats
# Program (415, '4501') waitlist: [] with 0 remaining seats
# Program (415, '5101') waitlist: [] with 0 remaining seats
# Program (416, '4109') waitlist: [] with 0 remaining seats
# Program (416, '4110') waitlist: [] with 0 remaining seats
# Program (416, '4111') waitlist: [] with 0 remaining seats
# Program (416, '4114') waitlist: [] with 0 remaining seats
# Program (416, '4125') waitlist: [] with 0 remaining seats
# Program (416, '5101') waitlist: [] with 0 remaining seats
# Program (420, '4110') waitlist: [] with 0 remaining seats
# Program (420, '4114') waitlist: [] with 0 remaining seats
# Program (420, '4181') waitlist: [] with 0 remaining seats
# Program (421, '5216') waitlist: [] with 0 remaining seats
# Program (423, '4110') waitlist: [] with 0 remaining seats
# Program (423, '4114') waitlist: [] with 0 remaining seats
# Program (424, '4110') waitlist: [] with 0 remaining seats
# Program (424, '4144') waitlist: [] with 0 remaining seats
# Program (424, '4146') waitlist: [] with 0 remaining seats
# Program (424, '4151') waitlist: [] with 0 remaining seats
# Program (424, '4153') waitlist: [] with 0 remaining seats
# Program (425, '4109') waitlist: [] with 0 remaining seats
# Program (425, '4110') waitlist: [] with 0 remaining seats
# Program (425, '4114') waitlist: [] with 0 remaining seats
# Program (425, '4121') waitlist: [] with 0 remaining seats
# Program (425, '4167') waitlist: [] with 0 remaining seats
# Program (426, '4107') waitlist: [] with 0 remaining seats
# Program (426, '4109') waitlist: [] with 0 remaining seats
# Program (426, '4110') waitlist: [] with 0 remaining seats
# Program (426, '4114') waitlist: [] with 0 remaining seats
# Program (426, '4125') waitlist: [] with 0 remaining seats
# Program (426, '4142') waitlist: [] with 0 remaining seats
# Program (426, '4144') waitlist: [] with 0 remaining seats
# Program (426, '4146') waitlist: [] with 0 remaining seats
# Program (426, '4178') waitlist: [] with 0 remaining seats
# Program (428, '4110') waitlist: [] with 0 remaining seats
# Program (428, '4114') waitlist: [] with 0 remaining seats
# Program (428, '4152') waitlist: [] with 0 remaining seats
# Program (430, '4183') waitlist: [] with 0 remaining seats
# Program (431, '4164') waitlist: [] with 0 remaining seats
# Program (432, '4109') waitlist: [] with 0 remaining seats
# Program (432, '4110') waitlist: [] with 0 remaining seats
# Program (432, '4111') waitlist: [] with 0 remaining seats
# Program (432, '4114') waitlist: [] with 0 remaining seats
# Program (432, '4125') waitlist: [] with 0 remaining seats
# Program (432, '4168') waitlist: [] with 0 remaining seats
# Program (433, '4197') waitlist: [] with 0 remaining seats
# Program (434, '4603') waitlist: [] with 0 remaining seats
# Program (434, '4604') waitlist: [] with 0 remaining seats
# Program (435, '5D01') waitlist: [] with 0 remaining seats
# Program (436, '4114') waitlist: [] with 0 remaining seats
# Program (436, '4146') waitlist: [] with 0 remaining seats
# Program (436, '4191') waitlist: [] with 0 remaining seats
# Program (436, '4198') waitlist: [] with 0 remaining seats
# Program (437, '410I') waitlist: [] with 0 remaining seats
# Program (437, '4110') waitlist: [] with 0 remaining seats
# Program (437, '4114') waitlist: [] with 0 remaining seats
# Program (437, '4195') waitlist: [] with 0 remaining seats
# Program (438, '4110') waitlist: [] with 0 remaining seats
# Program (438, '4114') waitlist: [] with 0 remaining seats
# Program (438, '411O') waitlist: [] with 0 remaining seats
# Program (438, '411P') waitlist: [] with 0 remaining seats
# Program (438, '411Q') waitlist: [] with 0 remaining seats
# Program (438, '4167') waitlist: [] with 0 remaining seats
# Program (439, '4109') waitlist: [] with 0 remaining seats
# Program (439, '4110') waitlist: [] with 0 remaining seats
# Program (439, '4111') waitlist: [] with 0 remaining seats
# Program (439, '411A') waitlist: [] with 0 remaining seats
# Program (440, '4110') waitlist: [] with 0 remaining seats
# Program (440, '4114') waitlist: [] with 0 remaining seats
# Program (440, '4125') waitlist: [] with 0 remaining seats
# Program (440, '4144') waitlist: [] with 0 remaining seats
# Program (441, '4109') waitlist: [] with 0 remaining seats
# Program (441, '4110') waitlist: [] with 0 remaining seats
# Program (441, '4114') waitlist: [] with 0 remaining seats
# Program (441, '4125') waitlist: [] with 0 remaining seats
# Program (441, '4144') waitlist: [] with 0 remaining seats
# Program (442, '4197') waitlist: [] with 0 remaining seats
# Program (209, '4109') waitlist: [] with 0 remaining seats
# Program (209, '4110') waitlist: [] with 0 remaining seats
# Program (209, '4114') waitlist: [] with 0 remaining seats
# Program (209, '4125') waitlist: [] with 0 remaining seats
# Program (209, '4144') waitlist: [] with 0 remaining seats
# Program (201, '4104') waitlist: [] with 0 remaining seats
# Program (201, '4107') waitlist: [] with 0 remaining seats
# Program (201, '4109') waitlist: [] with 0 remaining seats
# Program (201, '410V') waitlist: [] with 0 remaining seats
# Program (201, '4110') waitlist: [] with 0 remaining seats
# Program (201, '4111') waitlist: [] with 0 remaining seats
# Program (201, '4114') waitlist: [] with 0 remaining seats
# Program (201, '4125') waitlist: [] with 0 remaining seats
# Program (201, '4139') waitlist: [] with 0 remaining seats
# Program (201, '4146') waitlist: [] with 0 remaining seats
# Program (201, '4148') waitlist: [] with 0 remaining seats
# Program (201, '4149') waitlist: [] with 0 remaining seats
# Program (201, '4187') waitlist: [] with 0 remaining seats
# Program (202, '4107') waitlist: [] with 0 remaining seats
# Program (202, '4109') waitlist: [] with 0 remaining seats
# Program (202, '4110') waitlist: [] with 0 remaining seats
# Program (202, '4111') waitlist: [] with 0 remaining seats
# Program (202, '4114') waitlist: [] with 0 remaining seats
# Program (202, '411G') waitlist: [] with 0 remaining seats
# Program (202, '4125') waitlist: [] with 0 remaining seats
# Program (202, '4127') waitlist: [] with 0 remaining seats
# Program (202, '5101') waitlist: [] with 0 remaining seats
# Program (203, '4107') waitlist: [] with 0 remaining seats
# Program (203, '4109') waitlist: [] with 0 remaining seats
# Program (203, '4110') waitlist: [] with 0 remaining seats
# Program (203, '4111') waitlist: [] with 0 remaining seats
# Program (203, '4114') waitlist: [] with 0 remaining seats
# Program (203, '4125') waitlist: [] with 0 remaining seats
# Program (203, '4161') waitlist: [] with 0 remaining seats
# Program (203, '4501') waitlist: [] with 0 remaining seats
# Program (203, '5101') waitlist: [] with 0 remaining seats
# Program (203, '520F') waitlist: [] with 0 remaining seats
# Program (204, '4104') waitlist: [] with 0 remaining seats
# Program (204, '4107') waitlist: [] with 0 remaining seats
# Program (204, '4109') waitlist: [] with 0 remaining seats
# Program (204, '4110') waitlist: [] with 0 remaining seats
# Program (204, '4111') waitlist: [] with 0 remaining seats
# Program (204, '4114') waitlist: [] with 0 remaining seats
# Program (204, '4125') waitlist: [] with 0 remaining seats
# Program (204, '4136') waitlist: [] with 0 remaining seats
# Program (204, '4192') waitlist: [] with 0 remaining seats
# Program (205, '4105') waitlist: [] with 0 remaining seats
# Program (205, '4107') waitlist: [] with 0 remaining seats
# Program (205, '4109') waitlist: [] with 0 remaining seats
# Program (205, '4110') waitlist: [] with 0 remaining seats
# Program (205, '4111') waitlist: [] with 0 remaining seats
# Program (205, '4114') waitlist: [] with 0 remaining seats
# Program (205, '4125') waitlist: [] with 0 remaining seats
# Program (205, '4142') waitlist: [] with 0 remaining seats
# Program (205, '4145') waitlist: [] with 0 remaining seats
# Program (205, '520G') waitlist: [] with 0 remaining seats
# Program (205, '5267') waitlist: [] with 0 remaining seats
# Program (205, '5602') waitlist: [] with 0 remaining seats
# Program (205, '5604') waitlist: [] with 0 remaining seats
# Program (205, '5606') waitlist: [] with 0 remaining seats
# Program (206, '4104') waitlist: [] with 0 remaining seats
# Program (206, '4107') waitlist: [] with 0 remaining seats
# Program (206, '4109') waitlist: [] with 0 remaining seats
# Program (206, '4110') waitlist: [] with 0 remaining seats
# Program (206, '4114') waitlist: [] with 0 remaining seats
# Program (206, '4117') waitlist: [] with 0 remaining seats
# Program (206, '4123') waitlist: [] with 0 remaining seats
# Program (206, '4125') waitlist: [] with 0 remaining seats
# Program (206, '4144') waitlist: [] with 0 remaining seats
# Program (206, '4145') waitlist: [] with 0 remaining seats
# Program (206, '5101') waitlist: [] with 0 remaining seats
# Program (207, '4109') waitlist: [] with 0 remaining seats
# Program (207, '4110') waitlist: [] with 0 remaining seats
# Program (207, '4111') waitlist: [] with 0 remaining seats
# Program (207, '4114') waitlist: [] with 0 remaining seats
# Program (207, '4125') waitlist: [] with 0 remaining seats
# Program (207, '4188') waitlist: [] with 0 remaining seats
# Program (208, '4104') waitlist: [] with 0 remaining seats
# Program (208, '4107') waitlist: [] with 0 remaining seats
# Program (208, '4109') waitlist: [] with 0 remaining seats
# Program (208, '4110') waitlist: [] with 1 remaining seats
# Program (208, '4111') waitlist: [] with 0 remaining seats
# Program (208, '4114') waitlist: [] with 0 remaining seats
# Program (208, '4125') waitlist: [] with 0 remaining seats
# Program (208, '4127') waitlist: [] with 0 remaining seats
# Program (208, '5257') waitlist: [] with 0 remaining seats
# Program (208, '5296') waitlist: [] with 0 remaining seats
# Program (208, '5503') waitlist: [] with 0 remaining seats
# Program (210, '4107') waitlist: [] with 0 remaining seats
# Program (210, '4109') waitlist: [] with 0 remaining seats
# Program (210, '4110') waitlist: [] with 0 remaining seats
# Program (210, '4111') waitlist: [] with 0 remaining seats
# Program (210, '4114') waitlist: [] with 0 remaining seats
# Program (210, '4117') waitlist: [] with 0 remaining seats
# Program (210, '4123') waitlist: [] with 0 remaining seats
# Program (210, '4124') waitlist: [] with 0 remaining seats
# Program (210, '4125') waitlist: [] with 0 remaining seats
# Program (210, '5101') waitlist: [] with 0 remaining seats
# Program (210, '5216') waitlist: [] with 0 remaining seats
# Program (210, '5234') waitlist: [] with 0 remaining seats
# Program (211, '4107') waitlist: [] with 0 remaining seats
# Program (211, '4109') waitlist: [] with 0 remaining seats
# Program (211, '410Q') waitlist: [] with 0 remaining seats
# Program (211, '4110') waitlist: [] with 0 remaining seats
# Program (211, '4114') waitlist: [] with 0 remaining seats
# Program (211, '4125') waitlist: [] with 0 remaining seats
# Program (211, '4127') waitlist: [] with 0 remaining seats
# Program (211, '4130') waitlist: [] with 0 remaining seats
# Program (211, '4144') waitlist: [] with 0 remaining seats
# Program (211, '4146') waitlist: [] with 0 remaining seats
# Program (211, '4185') waitlist: [] with 0 remaining seats
# Program (212, '4109') waitlist: [] with 0 remaining seats
# Program (212, '4110') waitlist: [] with 0 remaining seats
# Program (212, '4114') waitlist: [] with 0 remaining seats
# Program (212, '4125') waitlist: [] with 0 remaining seats
# Program (212, '4144') waitlist: [] with 0 remaining seats
# Program (213, '4109') waitlist: [] with 0 remaining seats
# Program (213, '4110') waitlist: [] with 0 remaining seats
# Program (213, '4114') waitlist: [] with 0 remaining seats
# Program (213, '4125') waitlist: [] with 0 remaining seats
# Program (213, '4142') waitlist: [] with 0 remaining seats
# Program (213, '4144') waitlist: [] with 0 remaining seats
# Program (214, '4109') waitlist: [] with 0 remaining seats
# Program (214, '4110') waitlist: [] with 0 remaining seats
# Program (214, '4111') waitlist: [] with 0 remaining seats
# Program (214, '4114') waitlist: [] with 0 remaining seats
# Program (214, '4125') waitlist: [] with 0 remaining seats
# Program (214, '5101') waitlist: [] with 0 remaining seats
# Program (214, '520H') waitlist: [] with 0 remaining seats
# Program (214, '520I') waitlist: [] with 0 remaining seats
# Program (214, '520J') waitlist: [] with 0 remaining seats
# Program (214, '520K') waitlist: [] with 0 remaining seats
# Program (214, '520L') waitlist: [] with 0 remaining seats
# Program (214, '520M') waitlist: [] with 0 remaining seats
# Program (214, '520N') waitlist: [] with 0 remaining seats
# Program (214, '520O') waitlist: [] with 0 remaining seats
# Program (214, '521R') waitlist: [] with 0 remaining seats
# Program (215, '4109') waitlist: [] with 0 remaining seats
# Program (215, '4110') waitlist: [] with 0 remaining seats
# Program (215, '4114') waitlist: [] with 0 remaining seats
# Program (215, '4125') waitlist: [] with 0 remaining seats
# Program (215, '4144') waitlist: [] with 0 remaining seats
# Program (216, '4104') waitlist: [] with 0 remaining seats
# Program (216, '4107') waitlist: [] with 0 remaining seats
# Program (216, '4109') waitlist: [] with 0 remaining seats
# Program (216, '4110') waitlist: [] with 1 remaining seats
# Program (216, '4111') waitlist: [] with 0 remaining seats
# Program (216, '4114') waitlist: [] with 0 remaining seats
# Program (216, '4125') waitlist: [] with 0 remaining seats
# Program (216, '4127') waitlist: [] with 0 remaining seats
# Program (216, '4130') waitlist: [] with 0 remaining seats
# Program (216, '4146') waitlist: [] with 0 remaining seats
# Program (216, '4152') waitlist: [] with 0 remaining seats
# Program (216, '5101') waitlist: [] with 0 remaining seats
# Program (217, '4109') waitlist: [] with 0 remaining seats
# Program (217, '4110') waitlist: [] with 0 remaining seats
# Program (217, '4114') waitlist: [] with 0 remaining seats
# Program (217, '4125') waitlist: [] with 0 remaining seats
# Program (217, '4144') waitlist: [] with 0 remaining seats
# Program (218, '4109') waitlist: [] with 0 remaining seats
# Program (218, '4110') waitlist: [] with 0 remaining seats
# Program (218, '4111') waitlist: [] with 0 remaining seats
# Program (218, '4114') waitlist: [] with 0 remaining seats
# Program (218, '4125') waitlist: [] with 0 remaining seats
# Program (219, '4109') waitlist: [] with 0 remaining seats
# Program (219, '4110') waitlist: [] with 0 remaining seats
# Program (219, '4111') waitlist: [] with 0 remaining seats
# Program (219, '4114') waitlist: [] with 0 remaining seats
# Program (219, '4125') waitlist: [] with 0 remaining seats
# Program (219, '4127') waitlist: [] with 0 remaining seats
# Program (219, '4136') waitlist: [] with 0 remaining seats
# Program (219, '4192') waitlist: [] with 0 remaining seats
# Program (220, '4109') waitlist: [] with 0 remaining seats
# Program (220, '410P') waitlist: [] with 0 remaining seats
# Program (220, '4111') waitlist: [] with 0 remaining seats
# Program (220, '4114') waitlist: [] with 0 remaining seats
# Program (220, '411C') waitlist: [] with 0 remaining seats
# Program (220, '4124') waitlist: [] with 0 remaining seats
# Program (220, '4125') waitlist: [] with 0 remaining seats
# Program (220, '4136') waitlist: [] with 0 remaining seats
# Program (220, '4146') waitlist: [] with 0 remaining seats
# Program (220, '4151') waitlist: [] with 0 remaining seats
# Program (221, '4109') waitlist: [] with 0 remaining seats
# Program (221, '4110') waitlist: [] with 0 remaining seats
# Program (221, '4111') waitlist: [] with 0 remaining seats
# Program (221, '4114') waitlist: [] with 0 remaining seats
# Program (221, '4125') waitlist: [] with 0 remaining seats
# Program (222, '4109') waitlist: [] with 0 remaining seats
# Program (222, '4110') waitlist: [] with 0 remaining seats
# Program (222, '4111') waitlist: [] with 0 remaining seats
# Program (222, '4114') waitlist: [] with 0 remaining seats
# Program (222, '4124') waitlist: [] with 0 remaining seats
# Program (222, '4125') waitlist: [] with 0 remaining seats
# Program (223, '4104') waitlist: [] with 0 remaining seats
# Program (223, '4106') waitlist: [] with 0 remaining seats
# Program (223, '4107') waitlist: [] with 0 remaining seats
# Program (223, '4109') waitlist: [] with 0 remaining seats
# Program (223, '4110') waitlist: [] with 0 remaining seats
# Program (223, '4111') waitlist: [] with 0 remaining seats
# Program (223, '4114') waitlist: [] with 0 remaining seats
# Program (223, '4125') waitlist: [] with 0 remaining seats
# Program (223, '4127') waitlist: [] with 0 remaining seats
# Program (223, '4130') waitlist: [] with 0 remaining seats
# Program (223, '4142') waitlist: [] with 0 remaining seats
# Program (223, '4152') waitlist: [] with 0 remaining seats
# Program (223, '4155') waitlist: [] with 0 remaining seats
# Program (223, '4169') waitlist: [] with 0 remaining seats
# Program (223, '5101') waitlist: [] with 0 remaining seats
# Program (223, '5210') waitlist: [] with 0 remaining seats
# Program (223, '5243') waitlist: [] with 0 remaining seats
# Program (223, '5247') waitlist: [] with 0 remaining seats
# Program (223, '5258') waitlist: [] with 0 remaining seats
# Program (223, '5503') waitlist: [] with 0 remaining seats
# Program (223, '5507') waitlist: [] with 0 remaining seats
# Program (223, '5508') waitlist: [] with 0 remaining seats
# Program (223, '5509') waitlist: [] with 0 remaining seats
# Program (224, '4109') waitlist: [] with 0 remaining seats
# Program (224, '4110') waitlist: [] with 0 remaining seats
# Program (224, '4111') waitlist: [] with 0 remaining seats
# Program (224, '4114') waitlist: [] with 0 remaining seats
# Program (224, '4125') waitlist: [] with 0 remaining seats
# Program (224, '4142') waitlist: [] with 0 remaining seats
# Program (226, '4107') waitlist: [] with 0 remaining seats
# Program (226, '4109') waitlist: [] with 0 remaining seats
# Program (226, '4110') waitlist: [] with 0 remaining seats
# Program (226, '4114') waitlist: [] with 0 remaining seats
# Program (226, '4125') waitlist: [] with 0 remaining seats
# Program (226, '4127') waitlist: [] with 0 remaining seats
# Program (226, '4144') waitlist: [] with 0 remaining seats
# Program (226, '4145') waitlist: [] with 0 remaining seats
# Program (226, '4148') waitlist: [] with 0 remaining seats
# Program (226, '5101') waitlist: [] with 0 remaining seats
# Program (227, '4109') waitlist: [] with 0 remaining seats
# Program (227, '4110') waitlist: [] with 0 remaining seats
# Program (227, '4114') waitlist: [] with 0 remaining seats
# Program (227, '4125') waitlist: [] with 0 remaining seats
# Program (227, '4144') waitlist: [] with 0 remaining seats
# Program (228, '4104') waitlist: [] with 0 remaining seats
# Program (228, '4107') waitlist: [] with 0 remaining seats
# Program (228, '4109') waitlist: [] with 0 remaining seats
# Program (228, '410Z') waitlist: [] with 0 remaining seats
# Program (228, '4110') waitlist: [] with 0 remaining seats
# Program (228, '4114') waitlist: [] with 1 remaining seats
# Program (228, '4124') waitlist: [] with 0 remaining seats
# Program (228, '4125') waitlist: [] with 0 remaining seats
# Program (228, '4127') waitlist: [] with 0 remaining seats
# Program (228, '4144') waitlist: [] with 0 remaining seats
# Program (228, '5503') waitlist: [] with 0 remaining seats
# Program (228, '5507') waitlist: [] with 0 remaining seats
# Program (228, '5508') waitlist: [] with 0 remaining seats
# Program (229, '4107') waitlist: [] with 0 remaining seats
# Program (229, '4109') waitlist: [] with 0 remaining seats
# Program (229, '4110') waitlist: [] with 0 remaining seats
# Program (229, '4111') waitlist: [] with 0 remaining seats
# Program (229, '4114') waitlist: [] with 1 remaining seats
# Program (229, '4125') waitlist: [] with 0 remaining seats
# Program (229, '4185') waitlist: [] with 0 remaining seats
# Program (229, '5503') waitlist: [] with 0 remaining seats
# Program (229, '5507') waitlist: [] with 0 remaining seats
# Program (229, '5508') waitlist: [] with 0 remaining seats
# Program (230, '4107') waitlist: [] with 0 remaining seats
# Program (230, '4109') waitlist: [] with 0 remaining seats
# Program (230, '4110') waitlist: [] with 0 remaining seats
# Program (230, '4114') waitlist: [] with 0 remaining seats
# Program (230, '4125') waitlist: [] with 0 remaining seats
# Program (230, '4127') waitlist: [] with 0 remaining seats
# Program (230, '4130') waitlist: [] with 0 remaining seats
# Program (230, '4144') waitlist: [] with 0 remaining seats
# Program (230, '5101') waitlist: [] with 0 remaining seats
# Program (231, '4104') waitlist: [] with 0 remaining seats
# Program (231, '4107') waitlist: [] with 0 remaining seats
# Program (231, '4109') waitlist: [] with 0 remaining seats
# Program (231, '4110') waitlist: [] with 0 remaining seats
# Program (231, '4114') waitlist: [] with 0 remaining seats
# Program (231, '4125') waitlist: [] with 0 remaining seats
# Program (231, '4127') waitlist: [] with 0 remaining seats
# Program (231, '4144') waitlist: [] with 0 remaining seats
# Program (232, '4101') waitlist: [] with 0 remaining seats
# Program (232, '4109') waitlist: [] with 0 remaining seats
# Program (232, '4110') waitlist: [] with 0 remaining seats
# Program (232, '4111') waitlist: [] with 0 remaining seats
# Program (232, '4125') waitlist: [] with 0 remaining seats
# Program (232, '4130') waitlist: [] with 0 remaining seats
# Program (232, '4146') waitlist: [] with 0 remaining seats
# Program (232, '4153') waitlist: [] with 0 remaining seats
# Program (232, '4156') waitlist: [] with 0 remaining seats
# Program (232, '5101') waitlist: [] with 0 remaining seats
# Program (422, '4101') waitlist: [] with 0 remaining seats
# Program (422, '4109') waitlist: [] with 0 remaining seats
# Program (422, '4110') waitlist: [] with 0 remaining seats
# Program (422, '4111') waitlist: [] with 0 remaining seats
# Program (422, '4114') waitlist: [] with 0 remaining seats
# Program (422, '411H') waitlist: [] with 0 remaining seats
# Program (422, '4125') waitlist: [] with 0 remaining seats
# Program (422, '4127') waitlist: [] with 0 remaining seats
# Program (422, '4136') waitlist: [] with 0 remaining seats
# Program (422, '4603') waitlist: [] with 0 remaining seats
# Program (422, '4604') waitlist: [] with 0 remaining seats
# Program (427, '410E') waitlist: [] with 0 remaining seats
# Program (427, '410X') waitlist: [] with 0 remaining seats
# Program (427, '4111') waitlist: [] with 0 remaining seats
# Program (427, '4125') waitlist: [] with 0 remaining seats
# Program (427, '4164') waitlist: [] with 0 remaining seats
# Program (225, '4107') waitlist: [] with 0 remaining seats
# Program (225, '4109') waitlist: [] with 0 remaining seats
# Program (225, '4110') waitlist: [] with 0 remaining seats
# Program (225, '4111') waitlist: [] with 0 remaining seats
# Program (225, '4114') waitlist: [] with 0 remaining seats
# Program (225, '4125') waitlist: [] with 0 remaining seats
# Program (225, '4127') waitlist: [] with 0 remaining seats
# Program (225, '4146') waitlist: [] with 0 remaining seats
